# %%
# !git clone https://github.com/CarterKnuth/CSC786-DeePeR-Project.git
# %cd CSC786-DeePeR-Project
# Out:
# Cloning into 'CSC786-DeePeR-Project'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 51 (delta 14), reused 33 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 8.48 MiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/CSC786-DeePeR-Project

# %%
import pandas as pd
dataset = pd.read_csv('/content/CSC786-DeePeR-Project/dataset.csv')
dataset.head()
# Out:
#    page_id                                               text  label  \
# 0     1012            FLASH SALE | LIMITED TIME ONLY Shop Now      1
# 1      158                                Pillowcases & Shams      0
# 2      108                                     Write a review      0
# 3     1425  To start your return, simply click on the foll...      0
# 4     1658                newsletter signup (privacy policy)       0
#
#    Pattern Category
# 0           Urgency
# 1  Not Dark Pattern
# 2  Not Dark Pattern
# 3  Not Dark Pattern
# 4  Not Dark Pattern

# %% [markdown]
# The beginning of this dataset shows how it is formatted. Text showing how it is formatted, label 0/1: 0 - Not Dark Pattern; 1 - Dark Pattern/Lists the type of dark pattern

# %% [markdown]
# # Reflection
# There isn't a lot out there for dark pattern databases, I have not had enough time to create my own either. Krish Uppal uploaded their dataset two years ago on Kaggle for the public to use. Source URL for his page is found in my README.md.
